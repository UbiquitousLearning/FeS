# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import os

# %%
datasets = {"agnews": 1, "mnli": 0, "yahoo": 5, "yelp-full": 0}

filenames = [
    "filter_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log",
    "filter_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log",
]
full_set_acc= {"agnews": 0.93, "yahoo": 0.78, "yelp-full": 0.7, "mnli": 0.85}
labels = ["filter_1", "filter_5", "stale_1", "stale_5", "stale_10", "stale_20"]

show_list = [2,3,4,5]
filenames = [filenames[i] for i in show_list]
labels = [labels[i] for i in show_list]

# %%
colors=['r','g','b','y','c','m']

# %%
# round to accuracy
i=0
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
round_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
for dataset in datasets:
    if dataset == "agnews":
        root_path = f"/home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/{dataset}/all_1000/seed_42/pattern_{datasets[dataset]}/alpha_1_beta_0_gamma_100.0"
    else:
        root_path = f"/home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/{dataset}/all_1000/seed_42/pattern_{datasets[dataset]}/alpha_0_beta_0_gamma_100.0"

    fig = plt.figure()
    plt.title(dataset)
    for filename in filenames:
            
        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue


        # plt.title(log_path)
        iter = 1000
        phrase = 'aggregated model performance is'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        for line in f:
            if phrase in line:
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")
            continue

        # print(filename)
        # print(df)
        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, round is {idx}")
        acc_list[dataset].append(this_max_acc)
        round_list[dataset].append(idx)
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(labels, filenames.index(filename))
        plt.plot(range(iter),np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)])
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
    fig.savefig(f"../fig/a{i}.png")
    i = i+1
# Out:
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.8951315789473684, round is 107
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 0
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log
# max accuracy is 0.8975, round is 177
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 1
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.900921052631579, round is 178
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 2
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log
# max accuracy is 0.8972368421052631, round is 417
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 3
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.7845134997452878, round is 85
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 0
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log
# max accuracy is 0.7690269994905756, round is 159
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 1
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.7760570555272542, round is 250
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 2
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log
# max accuracy is 0.7616912888436067, round is 321
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 3
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6537833333333334, round is 26
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 0
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log
# max accuracy is 0.6688333333333333, round is 47
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 1
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.66955, round is 79
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 2
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log
# max accuracy is 0.66035, round is 85
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 3
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.5935, round is 32
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 0
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log
# max accuracy is 0.60594, round is 49
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 1
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.60722, round is 95
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 2
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log
# max accuracy is 0.58516, round is 43
# ['stale_1', 'stale_5', 'stale_10', 'stale_20'] 3

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}     
for dataset in datasets:
    if dataset == "agnews":
        root_path = f"/home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/{dataset}/all_1000/seed_42/pattern_{datasets[dataset]}/alpha_1_beta_0_gamma_100.0"
    else:
        root_path = f"/home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/{dataset}/all_1000/seed_42/pattern_{datasets[dataset]}/alpha_0_beta_0_gamma_100.0"
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Runtime")
    plt.ylabel("Accuracy")
    for filename in filenames:

        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        runtime = []
        train_runtime = []
        infer_runtime = []
        time_stamp = 0
        train_time_stamp = 0
        infer_time_stamp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                # TX2: train, 1s/sample, infer, 0.5s/sample
                train_time = sum(list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]) * 1 
                infer_time = sum(list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]) * 0.5
                
                time_stamp = time_stamp + train_time + infer_time # elasped time of all clients / energy consumption
                train_time_stamp = train_time + train_time_stamp
                infer_time_stamp = infer_time + infer_time_stamp

                runtime.append(time_stamp)
                train_runtime.append(train_time_stamp)
                infer_runtime.append(infer_time_stamp)
            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")

        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, runtime is {runtime[idx]}")
        acc_list[dataset].append(this_max_acc)
        runtime_list[dataset].append(runtime[idx])
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(len(runtime),len(list(map(float, y_mean))))
        plt.plot(runtime[:len(y_mean)],np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=4)
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=2,fontsize=15)
    fig.savefig(f"../fig/b{t}.png")
    t = t+1
# Out:
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.8951315789473684, runtime is 72212.5
# 143 142
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log
# max accuracy is 0.8975, runtime is 47341.5
# 206 206
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.900921052631579, runtime is 20746.0
# 412 412
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log
# max accuracy is 0.8972368421052631, runtime is 53704.0
# 424 423
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.7845134997452878, runtime is 178197.5
# 105 104
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log
# max accuracy is 0.7690269994905756, runtime is 126600.5
# 164 163
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.7760570555272542, runtime is 135900.0
# 327 327
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log
# max accuracy is 0.7616912888436067, runtime is 102746.0
# 348 347
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6537833333333334, runtime is 132305.0
# 29 29
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log
# max accuracy is 0.6688333333333333, runtime is 55348.5
# 49 48
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.66955, runtime is 48810.5
# 85 84
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log
# max accuracy is 0.66035, runtime is 23022.0
# 87 86
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.5935, runtime is 83114.0
# 36 35
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_5.log
# max accuracy is 0.60594, runtime is 26937.5
# 61 60
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.60722, runtime is 32957.0
# 100 99
# /home/cdq/FedPet/log/z-obsoleted/filter_stale_or_not/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100.0/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_20.log
# max accuracy is 0.58516, runtime is 4142.5
# 102 101

# %%
c=0
for dataset in datasets:
    fig = plt.figure()
    plt.title(f"{dataset}")
    plt.xlabel("1-Acc")
    plt.ylabel("Runtime")
    plt.scatter(1- np.array(acc_list[dataset]), np.array(runtime_list[dataset]),s=150,color=['r','g','b','y'])
    plt.savefig(f"../fig/c{c}.png")
    c=c+1
