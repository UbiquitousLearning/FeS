# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import os

# %%
datasets = {"agnews": 1, "mnli": 0, "yahoo": 5, "yelp-full": 0}
all_client_num_in_total_list = {"agnews": 100, "yahoo": 1000, "yelp-full": 1000, "mnli": 1000}
alphas = {"agnews": 1, "yahoo": 0, "yelp-full": 0, "mnli": 0}
gammas = {"agnews": 0.001, "yahoo": 0.001, "yelp-full": 0.001, "mnli": 100}
full_set_acc= {"agnews": 0.93, "yahoo": 0.78, "yelp-full": 0.7, "mnli": 0.85}

filenames = [
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log",
    # "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log",
    # "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log"
]
labels = ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale']

seed = 42

#

# %%
colors=['r','g','b','y','c','m','k']

# %%
# round to accuracy
i=0
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
round_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
for dataset in datasets:

    root_path = f"/home/cdq/FedPet/log/{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}"


    fig = plt.figure()
    plt.title(dataset)
    for filename in filenames:
            
        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue


        # plt.title(log_path)
        iter = 1000
        phrase = 'aggregated model performance is'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        for line in f:
            if phrase in line:
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")
            continue

        # print(filename)
        # print(df)
        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, round is {idx}")
        acc_list[dataset].append(this_max_acc)
        round_list[dataset].append(idx)
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(labels, filenames.index(filename))
        plt.plot(range(iter),np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)])
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
    fig.savefig(f"../fig/a{i}.png")
    i = i+1
# Out:
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.8919736842105264, round is 51
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 0
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.8731578947368421, round is 53
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 1
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.8809210526315789, round is 25
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 2
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.8892105263157895, round is 32
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 3
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.8647368421052631, round is 12
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 4
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.8844736842105263, round is 27
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 5
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6028527763627102, round is 46
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 0
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.5497707590422822, round is 43
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 1
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.4095771777890983, round is 13
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 2
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.6473764645950076, round is 58
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 3
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.5624044829342842, round is 25
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 4
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6156902699949057, round is 18
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 5
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6777833333333333, round is 21
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 0
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.6342, round is 9
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 1
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.653, round is 6
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 2
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.6642333333333333, round is 9
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 3
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.6566, round is 8
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 4
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6766333333333333, round is 21
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 5
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.5687, round is 19
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 0
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.54384, round is 35
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 1
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.54038, round is 21
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 2
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.59532, round is 30
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 3
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.59104, round is 20
# ['random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5', 'random_filter_1', 'stale_filter_1', 'stale'] 4
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log not exists

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}     
for dataset in datasets:

    root_path = f"/home/cdq/FedPet/log/{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}"
    
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Runtime")
    plt.ylabel("Accuracy")
    for filename in filenames:

        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        runtime = []
        train_runtime = []
        infer_runtime = []
        time_stamp = 0
        train_time_stamp = 0
        infer_time_stamp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                # TX2: train, 1s/sample, infer, 0.5s/sample, no comm. because bit fit is parameter efficient.
                train_time = sum(list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]) * 1 
                infer_time = sum(list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]) * 0.5
                
                time_stamp = time_stamp + train_time + infer_time # elasped time of all clients / energy consumption
                train_time_stamp = train_time + train_time_stamp
                infer_time_stamp = infer_time + infer_time_stamp

                runtime.append(time_stamp)
                train_runtime.append(train_time_stamp)
                infer_runtime.append(infer_time_stamp)
            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")

        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, runtime is {runtime[idx]}")
        acc_list[dataset].append(this_max_acc)
        runtime_list[dataset].append(runtime[idx])
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(len(runtime),len(list(map(float, y_mean))))
        plt.plot(runtime[:len(y_mean)],y_mean,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=4)
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=2,fontsize=15)
    fig.savefig(f"../fig/b{t}.pdf")
    t = t+1
# Out:
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.8796052631578948, runtime is 7403.0
# 25 25
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.8725, runtime is 9477.0
# 24 23
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.8790789473684211, runtime is 40999.0
# 22 22
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.8856578947368421, runtime is 59074.0
# 16 15
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.8647368421052631, runtime is 48420.0
# 13 13
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.8844736842105263, runtime is 146655.0
# 81 80
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.445746306673459, runtime is 2031.5
# 22 22
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.525522159959246, runtime is 4789.0
# 20 20
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.4095771777890983, runtime is 7829.0
# 17 17
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.6073357106469689, runtime is 24116.5
# 20 20
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.5624044829342842, runtime is 36005.0
# 71 71
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6156902699949057, runtime is 24179.5
# 33 33
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6402, runtime is 4121.0
# 10 10
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.5903166666666667, runtime is 4967.0
# 9 8
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.653, runtime is 12525.0
# 8 8
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.64555, runtime is 25128.0
# 8 8
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.6566, runtime is 34383.0
# 9 9
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6766333333333333, runtime is 114204.0
# 23 22
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.54284, runtime is 2253.0
# 11 11
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.53656, runtime is 4631.0
# 12 12
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.53066, runtime is 7974.0
# 10 10
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.5764, runtime is 18471.0
# 11 11
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.5519, runtime is 9595.0
# 9 9
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log not exists

# %%
c=0
for dataset in datasets:
    fig = plt.figure()
    plt.title(f"{dataset}")
    plt.xlabel("1-Acc")
    plt.ylabel("Runtime")
    plt.scatter(1- np.array(acc_list[dataset]), np.array(runtime_list[dataset]),s=150,color=colors[:len(acc_list[dataset])])
    plt.savefig(f"../fig/c{c}.png")
    c=c+1
