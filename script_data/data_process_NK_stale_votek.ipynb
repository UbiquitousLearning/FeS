# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import os

# %%
datasets = {"agnews": 1, "mnli": 0, "yahoo": 5, "yelp-full": 0}
all_client_num_in_total_list = {"agnews": 100, "yahoo": 1000, "yelp-full": 1000, "mnli": 1000}
alphas = {"agnews": 1, "yahoo": 0, "yelp-full": 0, "mnli": 0}
gammas = {"agnews": 0.001, "yahoo": 0.001, "yelp-full": 0.001, "mnli": 100}
full_set_acc= {"agnews": 0.93, "yahoo": 0.78, "yelp-full": 0.7, "mnli": 0.85}

filenames = [
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log",
    # "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log",
    # "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log",
    # "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log",
]

labels = ["filter 0.1", "filter 0.2", "filter 0.5", "filter 1"] # 'random_filter_0.1', 'random_filter_0.2', 'random_filter_0.5'

seed = 42

#

# %%
colors=['r','g','b','y','c','m','k']

# %%
# round to accuracy
i=0
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
round_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
for dataset in datasets:

    root_path = f"/home/cdq/FedPet/log/{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}"


    fig = plt.figure()
    plt.title(dataset)
    for filename in filenames:
            
        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue


        # plt.title(log_path)
        iter = 1000
        phrase = 'aggregated model performance is'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        for line in f:
            if phrase in line:
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")
            continue

        # print(filename)
        # print(df)
        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, round is {idx}")
        acc_list[dataset].append(this_max_acc)
        round_list[dataset].append(idx)
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(labels, filenames.index(filename))
        plt.plot(range(iter),np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)])
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
    fig.savefig(f"../fig/a{i}.png")
    i = i+1
# Out:
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.8905263157894737, round is 43
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 0
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.8830263157894737, round is 8
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 1
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.8873684210526316, round is 10
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 2
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.8843421052631579, round is 11
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 3
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6713194090677534, round is 64
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 0
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.745491594498217, round is 73
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 1
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.7343861436576669, round is 38
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 2
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.5640346408558329, round is 56
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 3
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6592333333333333, round is 22
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 0
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.65815, round is 12
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 1
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.6526, round is 10
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 2
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.6430333333333333, round is 7
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 3
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.59498, round is 11
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 0
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.61142, round is 19
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 1
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.61086, round is 26
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 2
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.60014, round is 25
# ['filter 0.1', 'filter 0.2', 'filter 0.5', 'filter 1'] 3

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}     
for dataset in datasets:

    root_path = f"/home/cdq/FedPet/log/{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}"
    
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Runtime")
    plt.ylabel("Accuracy")
    for filename in filenames:

        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        runtime = []
        train_runtime = []
        infer_runtime = []
        time_stamp = 0
        train_time_stamp = 0
        infer_time_stamp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                # TX2: train, 1s/sample, infer, 0.5s/sample, no comm. because bit fit is parameter efficient.
                train_time = sum(list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]) * 1 
                infer_time = sum(list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]) * 0.5
                
                time_stamp = time_stamp + train_time + infer_time # elasped time of all clients / energy consumption
                train_time_stamp = train_time + train_time_stamp
                infer_time_stamp = infer_time + infer_time_stamp

                runtime.append(time_stamp)
                train_runtime.append(train_time_stamp)
                infer_runtime.append(infer_time_stamp)
            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")

        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, runtime is {runtime[idx]}")
        acc_list[dataset].append(this_max_acc)
        runtime_list[dataset].append(runtime[idx])
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(len(runtime),len(list(map(float, y_mean))))
        plt.plot(runtime[:len(y_mean)],y_mean,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=4)
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=2,fontsize=15)
    fig.savefig(f"../fig/b{t}.pdf")
    t = t+1
# Out:
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.8925, runtime is 41574.5
# 98 98
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.8863157894736842, runtime is 54145.5
# 61 61
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.8836842105263157, runtime is 50600.0
# 23 23
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.8919736842105264, runtime is 34468.5
# 95 94
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.8731578947368421, runtime is 73058.5
# 93 93
# /home/cdq/FedPet/log/agnews/all_100/seed_6/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.8809210526315789, runtime is 65404.0
# 68 68
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.37768721344880285, runtime is 8.0
# 129 128
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.74253693326541, runtime is 51002.0
# 118 118
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.4292409577177789, runtime is 2163.0
# 95 95
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6028527763627102, runtime is 7341.0
# 86 86
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.5497707590422822, runtime is 12779.0
# 93 93
# /home/cdq/FedPet/log/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.4095771777890983, runtime is 7829.0
# 75 75
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6888666666666666, runtime is 17061.0
# 32 31
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.68305, runtime is 27458.0
# 25 25
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.6731666666666667, runtime is 28121.0
# 14 14
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6777833333333333, runtime is 11596.0
# 26 25
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.6342, runtime is 7842.0
# 11 10
# /home/cdq/FedPet/log/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.653, runtime is 12525.0
# 9 9
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.54614, runtime is 3331.0
# 41 40
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.54914, runtime is 15239.0
# 33 32
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.57362, runtime is 32074.0
# 25 25
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.5687, runtime is 4666.5
# 35 34
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.54384, runtime is 20646.0
# 41 40
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.54038, runtime is 26380.5
# 33 33

# %%
c=0
for dataset in datasets:
    fig = plt.figure()
    plt.title(f"{dataset}")
    plt.xlabel("1-Acc")
    plt.ylabel("Runtime")
    plt.scatter(1- np.array(acc_list[dataset]), np.array(runtime_list[dataset]),s=150,color=colors[:len(acc_list[dataset])])
    plt.savefig(f"../fig/c{c}.png")
    c=c+1
