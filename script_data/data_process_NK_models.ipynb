# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import os

# %%
datasets = {"agnews": 1, "mnli": 0, "yahoo": 5, "yelp-full": 0}
all_client_num_in_total_list = {"agnews": 100, "yahoo": 1000, "yelp-full": 1000, "mnli": 1000}
alphas = {"agnews": 1, "yahoo": 0, "yelp-full": 0, "mnli": 0}
gammas = {"agnews": 0.001, "yahoo":100, "yelp-full": 100, "mnli": 100}
full_set_acc= {"agnews": 0.93, "yahoo": 0.78, "yelp-full": 0.7, "mnli": 0.85}

filenames = [
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log",

]

labels = ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large']
seed = 99

#

# %%
colors=['r','g','b','y','c','m','k']

# %%
# round to accuracy
i=0
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
round_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
for dataset in datasets:

    root_path = f"/home/cdq/FedPet/log/{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}"


    fig = plt.figure()
    plt.title(dataset)
    for filename in filenames:
            
        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue


        # plt.title(log_path)
        iter = 1000
        phrase = 'aggregated model performance is'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        for line in f:
            if phrase in line:
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")
            continue

        # print(filename)
        # print(df)
        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, round is {idx}")
        acc_list[dataset].append(this_max_acc)
        round_list[dataset].append(idx)
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(labels, filenames.index(filename))
        plt.plot(range(iter),np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)])
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
    fig.savefig(f"../fig/a{i}.png")
    i = i+1
# Out:
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log
# max accuracy is 0.8425, round is 6
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 0
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log
# max accuracy is 0.8457894736842105, round is 6
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 1
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log
# max accuracy is 0.8367105263157895, round is 7
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 2
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log
# max accuracy is 0.8575, round is 1
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 3
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.8860526315789473, round is 7
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 4
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log
# max accuracy is 0.38634742740703004, round is 1
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 0
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log
# max accuracy is 0.3981660723382578, round is 5
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 1
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log
# max accuracy is 0.3828833418237392, round is 8
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 2
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log
# max accuracy is 0.41640346408558326, round is 2
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 3
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.4619460010188487, round is 11
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 4
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log
# max accuracy is 0.6536166666666666, round is 12
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 0
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log
# max accuracy is 0.6440166666666667, round is 10
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 1
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log
# max accuracy is 0.6594166666666667, round is 5
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 2
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log
# max accuracy is 0.6274666666666666, round is 7
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 3
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.629, round is 4
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 4
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log
# max accuracy is 0.42782, round is 9
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 0
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log
# max accuracy is 0.3783, round is 15
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 1
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log
# max accuracy is 0.41832, round is 6
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 2
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log
# max accuracy is 0.46476, round is 12
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 3
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.4919, round is 5
# ['albert-base-v2', 'bert-base-uncased', 'bert-large-uncased', 'roberta-base', 'roberta-large'] 4

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}     
for dataset in datasets:

    root_path = f"/home/cdq/FedPet/log/{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}"
    
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Runtime")
    plt.ylabel("Accuracy")
    for filename in filenames:

        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        runtime = []
        train_runtime = []
        infer_runtime = []
        time_stamp = 0
        train_time_stamp = 0
        infer_time_stamp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                # TX2: train, 1s/sample, infer, 0.5s/sample, no comm. because bit fit is parameter efficient.
                train_time = sum(list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]) * 1 
                infer_time = sum(list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]) * 0.5
                
                time_stamp = time_stamp + train_time + infer_time # elasped time of all clients / energy consumption
                train_time_stamp = train_time + train_time_stamp
                infer_time_stamp = infer_time + infer_time_stamp

                runtime.append(time_stamp)
                train_runtime.append(train_time_stamp)
                infer_runtime.append(infer_time_stamp)
            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")

        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, runtime is {runtime[idx]}")
        acc_list[dataset].append(this_max_acc)
        runtime_list[dataset].append(runtime[idx])
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(len(runtime),len(list(map(float, y_mean))))
        plt.plot(runtime[:len(y_mean)],y_mean,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=4)
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=2,fontsize=15)
    fig.savefig(f"../fig/b{t}.pdf")
    t = t+1
# Out:
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log
# max accuracy is 0.8425, runtime is 21333.0
# 122 25
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log
# max accuracy is 0.8457894736842105, runtime is 21569.0
# 85 17
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log
# max accuracy is 0.8367105263157895, runtime is 25070.0
# 40 8
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log
# max accuracy is 0.8575, runtime is 3226.0
# 82 17
# /home/cdq/FedPet/log/agnews/all_100/seed_99/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.8860526315789473, runtime is 25070.0
# 41 9
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log
# max accuracy is 0.38634742740703004, runtime is 1010.0
# 266 53
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log
# max accuracy is 0.3981660723382578, runtime is 5283.0
# 149 30
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log
# max accuracy is 0.3828833418237392, runtime is 8981.5
# 71 15
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log
# max accuracy is 0.41640346408558326, runtime is 2050.0
# 141 29
# /home/cdq/FedPet/log/mnli/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.4619460010188487, runtime is 13612.0
# 65 13
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log
# max accuracy is 0.6536166666666666, runtime is 54395.0
# 74 15
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log
# max accuracy is 0.6440166666666667, runtime is 42323.5
# 53 11
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log
# max accuracy is 0.6594166666666667, runtime is 18789.0
# 32 7
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log
# max accuracy is 0.6274666666666666, runtime is 27314.5
# 56 12
# /home/cdq/FedPet/log/yahoo/all_1000/seed_99/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.629, runtime is 15216.0
# 31 6
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_albert-base-v2_5_1_filter_-1.log
# max accuracy is 0.42782, runtime is 17023.5
# 111 22
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-base-uncased_5_1_filter_-1.log
# max accuracy is 0.3783, runtime is 32871.0
# 81 16
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_bert-large-uncased_5_1_filter_-1.log
# max accuracy is 0.41832, runtime is 10829.5
# 41 9
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-base_5_1_filter_-1.log
# max accuracy is 0.46476, runtime is 25273.0
# 79 16
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_99/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.4919, runtime is 8755.0
# 45 9

# %%
c=0
for dataset in datasets:
    fig = plt.figure()
    plt.title(f"{dataset}")
    plt.xlabel("1-Acc")
    plt.ylabel("Runtime")
    plt.scatter(1- np.array(acc_list[dataset]), np.array(runtime_list[dataset]),s=150,color=colors[:len(acc_list[dataset])])
    for idx in range(len(acc_list[dataset])):
        plt.text(1-acc_list[dataset][idx], runtime_list[dataset][idx], labels[idx], fontsize=12)
    plt.savefig(f"../fig/c{c}.png")
    c=c+1

# %%
acc_list
# Out:
# {'agnews': [0.25,
#   0.8594736842105263,
#   0.804078947368421,
#   0.8597368421052631,
#   0.8844736842105263],
#  'mnli': [0.36107997962302596,
#   0.3710646968925115,
#   0.3390728476821192,
#   0.36994396332144674,
#   0.6994396332144677],
#  'yahoo': [0.6560666666666667,
#   0.6551166666666667,
#   0.6609166666666667,
#   0.6130166666666667,
#   0.6257],
#  'yelp-full': [0.4313, 0.38052, 0.4177, 0.50742, 0.5273]}
