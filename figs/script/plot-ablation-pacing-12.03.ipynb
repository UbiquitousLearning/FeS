# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import os

# %%
# Model is roberta-base, zero-shot and few-shot hybrid
datasets = {"mnli": 0} # "agnews": 1, "mnli": 0, "yahoo": 5, "yelp-full": 0
all_client_num_in_total_list = {"agnews": 100, "yahoo": 1000, "yelp-full": 1000, "mnli": 1000}
alphas = {"agnews": 1, "yahoo": 1, "yelp-full": 0, "mnli": 0}
gammas = {"agnews": 0.001, "yahoo": 0.001, "yelp-full": 100, "mnli": 100}
full_set_acc= {"agnews": 0.93, "yahoo": 0.78, "yelp-full": 0.7, "mnli": 0.85}
train_data = {"agnews": 0, "yahoo": 64}


labels = []
filter = {"agnews": 0.1, "yahoo": 0.1, "yelp-full": 0.5, "mnli": 0.2}
k_list = [1,2,4] # data point
n_list = [1,2,4,8,16] # infer client num
f_list = [1,2,4,8,16] # infer frequency


seed = 6
# source file/log
root_path = "/Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3"
output_fig_path = "/Users/cdq/Desktop/opensource/FedPrompt/figs/pacing"

# plot hyper-para.
colors=['r','g','b','y','c','m','k','purple'] * 100

# per batch latency, bs = 4, msl = 256
train_latency_list = {"tx2+bitfit": 1, "tx2+full": 2}
infer_latency_list = {"tx2+bitfit": 0.5, "tx2+full": 1}
communication_latency_list = {"bitfit": 1000 * 2 / 1000 / 1, "full": 1000 * 2 / 1}

# %%
# round to accuracy
i=0
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
round_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
for dataset in datasets:

    log_root_path = os.path.join(root_path,f"{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}")

    filenames = []
    labels = []
    for k in k_list:
        for n in n_list:
            for f in f_list:
                filenames.append(f"ours++_fedpet_roberta-large_train_examples_64_f_{f}_n_{n}_k_{k}_filter_{filter[dataset]}.log")
                labels.append(f"k={k}, n={n}, f={f}")
                
    fig = plt.figure()
    plt.title(dataset)

    for filename in filenames:
            
        log_path = os.path.join(log_root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue


        # plt.title(log_path)
        iter = 1000
        phrase = 'aggregated model performance is'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        for line in f:
            if phrase in line:
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")
            continue

        # print(filename)
        # print(df)
        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, round is {idx}")
        acc_list[dataset].append(this_max_acc)
        round_list[dataset].append(idx)
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(labels, filenames.index(filename))
        print(range(iter))
        print(np.array(y_mean)/full_set_acc[dataset])
        print(colors[filenames.index(filename)])
        print(labels[filenames.index(filename)])
        plt.plot(range(iter),np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)])
    # fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
    fig.savefig(os.path.join(output_fig_path, f"eval-ablation-{dataset}-round-12.03.pdf"))
    i = i+1
# Out:
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_1_k_1_filter_0.2.log
# max accuracy is 0.7039225674987264, round is 18
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 0
# range(0, 22)
# [[0.4443379 ]
#  [0.45788259]
#  [0.37889185]
#  [0.67555662]
#  [0.61334692]
#  [0.56216475]
#  [0.73201283]
#  [0.72889635]
#  [0.75646519]
#  [0.68694375]
#  [0.80728776]
#  [0.76809206]
#  [0.78487309]
#  [0.77624285]
#  [0.79086632]
#  [0.78187648]
#  [0.80560966]
#  [0.80752749]
#  [0.8281442 ]
#  [0.7956609 ]
#  [0.82526745]
#  [0.81855503]]
# r
# k=1, n=1, f=1
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_1_k_1_filter_0.2.log
# max accuracy is 0.6782475802343352, round is 20
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 1
# range(0, 25)
# [[0.4443379 ]
#  [0.42587876]
#  [0.38236792]
#  [0.57127446]
#  [0.51337988]
#  [0.61358665]
#  [0.7030056 ]
#  [0.73632795]
#  [0.73225255]
#  [0.69425549]
#  [0.73249228]
#  [0.71499206]
#  [0.73800605]
#  [0.78211621]
#  [0.76281802]
#  [0.77492434]
#  [0.72625933]
#  [0.76677355]
#  [0.79578077]
#  [0.76617422]
#  [0.79793833]
#  [0.76809206]
#  [0.77156813]
#  [0.78978754]
#  [0.78259567]]
# g
# k=1, n=1, f=2
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_1_k_1_filter_0.2.log
# max accuracy is 0.723586347427407, round is 23
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 2
# range(0, 25)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.65314195]
#  [0.66968326]
#  [0.68946091]
#  [0.74819454]
#  [0.73309161]
#  [0.74603698]
#  [0.72961553]
#  [0.79122591]
#  [0.78906835]
#  [0.80776722]
#  [0.77732163]
#  [0.81999341]
#  [0.82994217]
#  [0.84037038]
#  [0.83653472]
#  [0.84049025]
#  [0.83941147]
#  [0.83473675]
#  [0.84444578]
#  [0.85127806]
#  [0.82706542]]
# b
# k=1, n=1, f=4
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_1_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_1_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_2_k_1_filter_0.2.log
# max accuracy is 0.6009169638308711, round is 10
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 5
# range(0, 19)
# [[0.4443379 ]
#  [0.44949207]
#  [0.4291151 ]
#  [0.38440562]
#  [0.39231668]
#  [0.53831171]
#  [0.41401217]
#  [0.50966408]
#  [0.49396182]
#  [0.57391148]
#  [0.70696113]
#  [0.59860358]
#  [0.63935753]
#  [0.58853496]
#  [0.61826136]
#  [0.61766204]
#  [0.68706362]
#  [0.62653202]
#  [0.66069342]]
# m
# k=1, n=2, f=1
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_2_k_1_filter_0.2.log
# max accuracy is 0.6902699949057565, round is 17
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 6
# range(0, 21)
# [[0.4443379 ]
#  [0.42587876]
#  [0.43390968]
#  [0.60411735]
#  [0.69725211]
#  [0.53411645]
#  [0.51961284]
#  [0.66560786]
#  [0.56024692]
#  [0.76773246]
#  [0.74579725]
#  [0.75514668]
#  [0.7919451 ]
#  [0.80692817]
#  [0.75646519]
#  [0.77552366]
#  [0.80213359]
#  [0.81208235]
#  [0.79949657]
#  [0.79410266]
#  [0.79841779]]
# k
# k=1, n=2, f=2
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_2_k_1_filter_0.2.log
# max accuracy is 0.7096281202241467, round is 24
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 7
# range(0, 25)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.50990381]
#  [0.69569387]
#  [0.48233496]
#  [0.75430763]
#  [0.74483833]
#  [0.71427287]
#  [0.72613946]
#  [0.75418777]
#  [0.77012975]
#  [0.70720086]
#  [0.77024962]
#  [0.80369183]
#  [0.79410266]
#  [0.82886338]
#  [0.80009589]
#  [0.7997363 ]
#  [0.81519883]
#  [0.8034521 ]
#  [0.81543855]
#  [0.82071259]
#  [0.83485661]]
# purple
# k=1, n=2, f=4
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_2_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_2_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_4_k_1_filter_0.2.log
# max accuracy is 0.6752929190015283, round is 17
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 10
# range(0, 19)
# [[0.4443379 ]
#  [0.41988553]
#  [0.42659794]
#  [0.52632525]
#  [0.56899703]
#  [0.57942525]
#  [0.65673789]
#  [0.63971712]
#  [0.61562434]
#  [0.65482005]
#  [0.69845075]
#  [0.72530041]
#  [0.76869138]
#  [0.75155075]
#  [0.78475323]
#  [0.77252704]
#  [0.78978754]
#  [0.79446226]
#  [0.73201283]]
# b
# k=1, n=4, f=1
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_4_k_1_filter_0.2.log
# max accuracy is 0.6454406520631686, round is 18
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 11
# range(0, 19)
# [[0.4443379 ]
#  [0.42587876]
#  [0.41664919]
#  [0.47550268]
#  [0.61466543]
#  [0.50726679]
#  [0.50103383]
#  [0.70516317]
#  [0.70120764]
#  [0.65937491]
#  [0.64846723]
#  [0.71415301]
#  [0.7033652 ]
#  [0.67627581]
#  [0.71331396]
#  [0.67951215]
#  [0.69425549]
#  [0.74915346]
#  [0.75934194]]
# y
# k=1, n=4, f=2
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_4_k_1_filter_0.2.log
# max accuracy is 0.7200203769740193, round is 18
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 12
# range(0, 21)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.57594918]
#  [0.58709658]
#  [0.62797039]
#  [0.66980312]
#  [0.75802343]
#  [0.66596746]
#  [0.76785233]
#  [0.66680651]
#  [0.81160289]
#  [0.76797219]
#  [0.78307513]
#  [0.82622636]
#  [0.78331485]
#  [0.77660244]
#  [0.8470828 ]
#  [0.80872614]
#  [0.81951395]]
# c
# k=1, n=4, f=4
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_4_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_4_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_8_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_8_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_8_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_8_k_1_filter_0.2.log
# max accuracy is 0.739174732552216, round is 46
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 18
# range(0, 51)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.57942525]
#  [0.68358755]
#  [0.6901801 ]
#  [0.75250966]
#  [0.62940877]
#  [0.69533427]
#  [0.75946181]
#  [0.75394804]
#  [0.7239819 ]
#  [0.72434149]
#  [0.7730065 ]
#  [0.72338258]
#  [0.69341644]
#  [0.75346858]
#  [0.76102005]
#  [0.7317731 ]
#  [0.78511282]
#  [0.78930808]
#  [0.7997363 ]
#  [0.79877738]
#  [0.82179138]
#  [0.83593539]
#  [0.81507896]
#  [0.84120943]
#  [0.84696293]
#  [0.84120943]
#  [0.84252794]
#  [0.82502772]
#  [0.82634623]
#  [0.83233946]
#  [0.82155165]
#  [0.82850379]
#  [0.82874352]
#  [0.84001079]
#  [0.84912049]
#  [0.85163765]
#  [0.843367  ]
#  [0.84528483]
#  [0.84684307]
#  [0.84864104]
#  [0.81759612]
#  [0.84936022]
#  [0.86961733]
#  [0.83881214]
#  [0.85906925]
#  [0.86614126]
#  [0.86829882]]
# b
# k=1, n=8, f=8
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_8_k_1_filter_0.2.log
# max accuracy is 0.7129903209373408, round is 48
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 19
# range(0, 53)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.57942525]
#  [0.68358755]
#  [0.6901801 ]
#  [0.74987264]
#  [0.73908483]
#  [0.75874262]
#  [0.73021486]
#  [0.64810764]
#  [0.75274939]
#  [0.7733661 ]
#  [0.77000989]
#  [0.77768122]
#  [0.75826316]
#  [0.78954781]
#  [0.77072908]
#  [0.77959905]
#  [0.80309251]
#  [0.80525007]
#  [0.77456474]
#  [0.77072908]
#  [0.80944533]
#  [0.79518144]
#  [0.78679093]
#  [0.79086632]
#  [0.79829792]
#  [0.80417129]
#  [0.79530131]
#  [0.78295526]
#  [0.79038686]
#  [0.81759612]
#  [0.78499296]
#  [0.81400018]
#  [0.79661982]
#  [0.81987354]
#  [0.82730515]
#  [0.80572953]
#  [0.81400018]
#  [0.77696203]
#  [0.80992478]
#  [0.75490696]
#  [0.81543855]
#  [0.80536993]
#  [0.78882862]
#  [0.80189386]
#  [0.83881214]
#  [0.82646609]
#  [0.81423991]
#  [0.79542117]
#  [0.82790447]]
# y
# k=1, n=8, f=16
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_16_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_16_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_16_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_16_k_1_filter_0.2.log
# max accuracy is 0.7220580743759552, round is 46
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 23
# range(0, 47)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.57942525]
#  [0.68358755]
#  [0.6901801 ]
#  [0.62269635]
#  [0.53351713]
#  [0.6502652 ]
#  [0.7445986 ]
#  [0.74735549]
#  [0.76701327]
#  [0.80093494]
#  [0.76102005]
#  [0.7429205 ]
#  [0.737167  ]
#  [0.77947919]
#  [0.80201372]
#  [0.78942795]
#  [0.77324623]
#  [0.79721914]
#  [0.76821192]
#  [0.80560966]
#  [0.81915436]
#  [0.81675706]
#  [0.7882293 ]
#  [0.81447964]
#  [0.82670582]
#  [0.79446226]
#  [0.80189386]
#  [0.79506158]
#  [0.79518144]
#  [0.8108837 ]
#  [0.76293788]
#  [0.82287016]
#  [0.82910311]
#  [0.843367  ]
#  [0.82742501]
#  [0.84552456]
#  [0.83042162]
#  [0.83881214]
#  [0.82646609]
#  [0.83509634]
#  [0.83449702]
#  [0.84552456]
#  [0.84948009]]
# purple
# k=1, n=16, f=8
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_16_k_1_filter_0.2.log
# max accuracy is 0.7168619460010188, round is 49
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 24
# range(0, 52)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.57942525]
#  [0.68358755]
#  [0.6901801 ]
#  [0.74987264]
#  [0.73908483]
#  [0.75874262]
#  [0.73021486]
#  [0.64810764]
#  [0.75274939]
#  [0.76653382]
#  [0.76545504]
#  [0.77612298]
#  [0.78786971]
#  [0.79913698]
#  [0.79014713]
#  [0.80848641]
#  [0.77276677]
#  [0.81004465]
#  [0.80596925]
#  [0.77036948]
#  [0.82287016]
#  [0.80848641]
#  [0.80045549]
#  [0.80860627]
#  [0.80225345]
#  [0.8071679 ]
#  [0.79110605]
#  [0.76257829]
#  [0.8129214 ]
#  [0.81244194]
#  [0.82730515]
#  [0.80369183]
#  [0.82047287]
#  [0.82191124]
#  [0.79745887]
#  [0.82694555]
#  [0.83305864]
#  [0.81675706]
#  [0.78978754]
#  [0.81855503]
#  [0.81999341]
#  [0.82934284]
#  [0.83485661]
#  [0.8355758 ]
#  [0.81999341]
#  [0.843367  ]
#  [0.82478799]
#  [0.8355758 ]]
# r
# k=1, n=16, f=16
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_1_k_2_filter_0.2.log
# max accuracy is 0.5345899133978604, round is 17
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 25
# range(0, 23)
# [[0.4443379 ]
#  [0.46135866]
#  [0.3780528 ]
#  [0.58697672]
#  [0.43199185]
#  [0.48605076]
#  [0.54754128]
#  [0.41113542]
#  [0.54514399]
#  [0.57606904]
#  [0.55653112]
#  [0.57367175]
#  [0.61334692]
#  [0.57786701]
#  [0.58469929]
#  [0.60627491]
#  [0.57475053]
#  [0.62892931]
#  [0.59129184]
#  [0.61202841]
#  [0.62041893]
#  [0.57439094]
#  [0.59656588]]
# g
# k=2, n=1, f=1
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_1_k_2_filter_0.2.log
# max accuracy is 0.7208354559347937, round is 21
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 26
# range(0, 22)
# [[0.4443379 ]
#  [0.42587876]
#  [0.43978305]
#  [0.52224986]
#  [0.5687573 ]
#  [0.70624195]
#  [0.70720086]
#  [0.76054059]
#  [0.76461598]
#  [0.69809116]
#  [0.75358845]
#  [0.79506158]
#  [0.78774984]
#  [0.79122591]
#  [0.80477061]
#  [0.82334961]
#  [0.82958257]
#  [0.83785323]
#  [0.82095232]
#  [0.84264781]
#  [0.84768212]
#  [0.84804171]]
# b
# k=2, n=1, f=2
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_1_k_2_filter_0.2.log
# max accuracy is 0.7210392256749872, round is 22
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 27
# range(0, 25)
# [[0.4443379 ]
#  [0.42587876]
#  [0.38236792]
#  [0.40550178]
#  [0.48353361]
#  [0.61310719]
#  [0.64307333]
#  [0.48940697]
#  [0.75143088]
#  [0.74328009]
#  [0.74280064]
#  [0.76173923]
#  [0.78751011]
#  [0.78319499]
#  [0.82430853]
#  [0.82179138]
#  [0.75994127]
#  [0.83509634]
#  [0.81603788]
#  [0.82059273]
#  [0.83857241]
#  [0.83533607]
#  [0.84828144]
#  [0.82898325]
#  [0.84732253]]
# y
# k=2, n=1, f=4
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_1_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_1_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_2_k_2_filter_0.2.log
# max accuracy is 0.5806418746816098, round is 13
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 30
# range(0, 22)
# [[0.4443379 ]
#  [0.47010878]
#  [0.51278056]
#  [0.51050313]
#  [0.48413293]
#  [0.57546972]
#  [0.5538941 ]
#  [0.53615415]
#  [0.64379251]
#  [0.57163405]
#  [0.60795301]
#  [0.50798598]
#  [0.57259297]
#  [0.68310809]
#  [0.65901531]
#  [0.65721734]
#  [0.62749094]
#  [0.63000809]
#  [0.65913518]
#  [0.64750832]
#  [0.64163495]
#  [0.67244014]]
# k
# k=2, n=2, f=1
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_2_k_2_filter_0.2.log
# max accuracy is 0.5746306673458992, round is 22
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 31
# range(0, 23)
# [[0.4443379 ]
#  [0.4443379 ]
#  [0.37445686]
#  [0.44277966]
#  [0.43606724]
#  [0.43870426]
#  [0.52644512]
#  [0.56324353]
#  [0.57463067]
#  [0.6235354 ]
#  [0.52944173]
#  [0.61622367]
#  [0.59368913]
#  [0.53387672]
#  [0.6164634 ]
#  [0.64259387]
#  [0.6671661 ]
#  [0.6198196 ]
#  [0.62832999]
#  [0.64103563]
#  [0.62569297]
#  [0.63971712]
#  [0.67603608]]
# purple
# k=2, n=2, f=2
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_2_k_2_filter_0.2.log
# max accuracy is 0.705145185939888, round is 18
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 32
# range(0, 22)
# [[0.4443379 ]
#  [0.42587876]
#  [0.43343022]
#  [0.60483653]
#  [0.58709658]
#  [0.53711306]
#  [0.68466633]
#  [0.72410177]
#  [0.70312547]
#  [0.70084804]
#  [0.79638009]
#  [0.80165413]
#  [0.76341734]
#  [0.76941057]
#  [0.78463336]
#  [0.81591801]
#  [0.82023314]
#  [0.80896587]
#  [0.82958257]
#  [0.80620898]
#  [0.82526745]
#  [0.8149591 ]]
# r
# k=2, n=2, f=4
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_2_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_2_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_4_k_2_filter_0.2.log
# max accuracy is 0.40804890473764643, round is 5
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 35
# range(0, 17)
# [[0.4443379 ]
#  [0.41700878]
#  [0.42779659]
#  [0.40538192]
#  [0.43630697]
#  [0.48005753]
#  [0.44961194]
#  [0.47358485]
#  [0.45704354]
#  [0.44685505]
#  [0.45212909]
#  [0.44901262]
#  [0.46255731]
#  [0.46099907]
#  [0.46075934]
#  [0.45932097]
#  [0.46627311]]
# y
# k=2, n=4, f=1
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_4_k_2_filter_0.2.log
# max accuracy is 0.7370351502801834, round is 16
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 36
# range(0, 19)
# [[0.4443379 ]
#  [0.43295077]
#  [0.5011537 ]
#  [0.48844805]
#  [0.49240358]
#  [0.63288484]
#  [0.66093315]
#  [0.79290402]
#  [0.77240718]
#  [0.77804081]
#  [0.83905187]
#  [0.85223697]
#  [0.81915436]
#  [0.85223697]
#  [0.8565521 ]
#  [0.83245932]
#  [0.86710018]
#  [0.84600402]
#  [0.85403494]]
# c
# k=2, n=4, f=2
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_4_k_2_filter_0.2.log
# max accuracy is 0.5718797758532858, round is 8
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 37
# range(0, 24)
# [[0.4443379 ]
#  [0.42587876]
#  [0.38608373]
#  [0.50031464]
#  [0.6144257 ]
#  [0.55149681]
#  [0.44373858]
#  [0.55952773]
#  [0.67279974]
#  [0.62149771]
#  [0.48125618]
#  [0.56156543]
#  [0.64906655]
#  [0.56396272]
#  [0.56719907]
#  [0.57774715]
#  [0.64690899]
#  [0.61370651]
#  [0.57666836]
#  [0.60459681]
#  [0.61658326]
#  [0.60315843]
#  [0.59153157]
#  [0.62497378]]
# m
# k=2, n=4, f=4
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_4_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_4_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_8_k_2_filter_0.2.log not exists
# ...
# range(0, 17)
# [[0.4443379 ]
#  [0.42024512]
#  [0.42863564]
#  [0.40370381]
#  [0.41233406]
#  [0.39986815]
#  [0.39627221]
#  [0.3969914 ]
#  [0.39771059]
#  [0.39914896]
#  [0.39639208]
#  [0.39615235]
#  [0.39735099]
#  [0.39819005]
#  [0.39795032]
#  [0.39555303]
#  [0.39567289]]
# c
# k=4, n=4, f=1
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_4_k_4_filter_0.2.log
# max accuracy is 0.37768721344880285, round is 0
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 61
# range(0, 20)
# [[0.4443379 ]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]
#  [0.41700878]]
# m
# k=4, n=4, f=2
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_4_k_4_filter_0.2.log
# max accuracy is 0.721141110545084, round is 20
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 62
# range(0, 21)
# [[0.4443379 ]
#  [0.43295077]
#  [0.52632525]
#  [0.58110335]
#  [0.51781487]
#  [0.69089928]
#  [0.69581373]
#  [0.66249138]
#  [0.73381079]
#  [0.69749183]
#  [0.8112433 ]
#  [0.80572953]
#  [0.77000989]
#  [0.78727038]
#  [0.82922298]
#  [0.83833268]
#  [0.71631057]
#  [0.83617512]
#  [0.79122591]
#  [0.82287016]
#  [0.84840131]]
# k
# k=4, n=4, f=4
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_4_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_4_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_8_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_8_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_8_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_8_k_4_filter_0.2.log
# max accuracy is 0.6627610799796231, round is 41
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 68
# range(0, 49)
# [[0.4443379 ]
#  [0.42587876]
#  [0.41628959]
#  [0.49983519]
#  [0.56324353]
#  [0.41712864]
#  [0.44901262]
#  [0.62797039]
#  [0.71199545]
#  [0.70096791]
#  [0.66536813]
#  [0.65242276]
#  [0.64690899]
#  [0.68490606]
#  [0.74747535]
#  [0.73968416]
#  [0.71870786]
#  [0.63348416]
#  [0.76113991]
#  [0.67196068]
#  [0.67148123]
#  [0.72841689]
#  [0.7145126 ]
#  [0.69617332]
#  [0.71127626]
#  [0.67315933]
#  [0.69845075]
#  [0.74999251]
#  [0.76329747]
#  [0.74675617]
#  [0.7503521 ]
#  [0.73261215]
#  [0.75766384]
#  [0.74771508]
#  [0.75670492]
#  [0.75047197]
#  [0.71547152]
#  [0.75107129]
#  [0.7429205 ]
#  [0.75754398]
#  [0.75862276]
#  [0.77971892]
#  [0.76833179]
#  [0.77911959]
#  [0.77156813]
#  [0.76941057]
#  [0.75910221]
#  [0.77288664]
#  [0.77252704]]
# c
# k=4, n=8, f=8
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_8_k_4_filter_0.2.log
# max accuracy is 0.7317371370351503, round is 48
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 69
# range(0, 53)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.60207965]
#  [0.54286656]
#  [0.54190764]
#  [0.73261215]
#  [0.55844895]
#  [0.6708819 ]
#  [0.71894759]
#  [0.78535255]
#  [0.74447874]
#  [0.78031824]
#  [0.75502682]
#  [0.76054059]
#  [0.78511282]
#  [0.78894849]
#  [0.77120853]
#  [0.79482185]
#  [0.82694555]
#  [0.76641395]
#  [0.76989002]
#  [0.78163675]
#  [0.81567828]
#  [0.81471937]
#  [0.79626023]
#  [0.81364059]
#  [0.81639747]
#  [0.82622636]
#  [0.7033652 ]
#  [0.82251056]
#  [0.8186749 ]
#  [0.82742501]
#  [0.83449702]
#  [0.84408618]
#  [0.81879476]
#  [0.85415481]
#  [0.84804171]
#  [0.81435977]
#  [0.83893201]
#  [0.84612388]
#  [0.81172275]
#  [0.83461688]
#  [0.85295616]
#  [0.85571304]
#  [0.81471937]
#  [0.84804171]
#  [0.86086722]
#  [0.83437715]
#  [0.84959995]
#  [0.84696293]
#  [0.83869228]]
# m
# k=4, n=8, f=16
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_16_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_16_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_16_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_16_k_4_filter_0.2.log
# max accuracy is 0.6937340804890474, round is 26
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 73
# range(0, 46)
# [[0.4443379 ]
#  [0.42587876]
#  [0.48365347]
#  [0.53795211]
#  [0.51625663]
#  [0.68538551]
#  [0.65865572]
#  [0.7392047 ]
#  [0.69029996]
#  [0.63983698]
#  [0.70252615]
#  [0.71631057]
#  [0.66213179]
#  [0.7466363 ]
#  [0.71403314]
#  [0.7202661 ]
#  [0.74423901]
#  [0.72122502]
#  [0.75418777]
#  [0.78607174]
#  [0.77276677]
#  [0.76413653]
#  [0.76533517]
#  [0.76785233]
#  [0.68083066]
#  [0.7770819 ]
#  [0.81615774]
#  [0.77744149]
#  [0.74256091]
#  [0.81052411]
#  [0.79242456]
#  [0.80045549]
#  [0.80848641]
#  [0.78810944]
#  [0.81531869]
#  [0.78319499]
#  [0.78547242]
#  [0.77971892]
#  [0.77756136]
#  [0.80357196]
#  [0.77036948]
#  [0.80249318]
#  [0.81028438]
#  [0.80525007]
#  [0.80788709]
#  [0.8112433 ]]
# g
# k=4, n=16, f=8
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_16_k_4_filter_0.2.log
# max accuracy is 0.7445746306673459, round is 49
# ['k=1, n=1, f=1', 'k=1, n=1, f=2', 'k=1, n=1, f=4', 'k=1, n=1, f=8', 'k=1, n=1, f=16', 'k=1, n=2, f=1', 'k=1, n=2, f=2', 'k=1, n=2, f=4', 'k=1, n=2, f=8', 'k=1, n=2, f=16', 'k=1, n=4, f=1', 'k=1, n=4, f=2', 'k=1, n=4, f=4', 'k=1, n=4, f=8', 'k=1, n=4, f=16', 'k=1, n=8, f=1', 'k=1, n=8, f=2', 'k=1, n=8, f=4', 'k=1, n=8, f=8', 'k=1, n=8, f=16', 'k=1, n=16, f=1', 'k=1, n=16, f=2', 'k=1, n=16, f=4', 'k=1, n=16, f=8', 'k=1, n=16, f=16', 'k=2, n=1, f=1', 'k=2, n=1, f=2', 'k=2, n=1, f=4', 'k=2, n=1, f=8', 'k=2, n=1, f=16', 'k=2, n=2, f=1', 'k=2, n=2, f=2', 'k=2, n=2, f=4', 'k=2, n=2, f=8', 'k=2, n=2, f=16', 'k=2, n=4, f=1', 'k=2, n=4, f=2', 'k=2, n=4, f=4', 'k=2, n=4, f=8', 'k=2, n=4, f=16', 'k=2, n=8, f=1', 'k=2, n=8, f=2', 'k=2, n=8, f=4', 'k=2, n=8, f=8', 'k=2, n=8, f=16', 'k=2, n=16, f=1', 'k=2, n=16, f=2', 'k=2, n=16, f=4', 'k=2, n=16, f=8', 'k=2, n=16, f=16', 'k=4, n=1, f=1', 'k=4, n=1, f=2', 'k=4, n=1, f=4', 'k=4, n=1, f=8', 'k=4, n=1, f=16', 'k=4, n=2, f=1', 'k=4, n=2, f=2', 'k=4, n=2, f=4', 'k=4, n=2, f=8', 'k=4, n=2, f=16', 'k=4, n=4, f=1', 'k=4, n=4, f=2', 'k=4, n=4, f=4', 'k=4, n=4, f=8', 'k=4, n=4, f=16', 'k=4, n=8, f=1', 'k=4, n=8, f=2', 'k=4, n=8, f=4', 'k=4, n=8, f=8', 'k=4, n=8, f=16', 'k=4, n=16, f=1', 'k=4, n=16, f=2', 'k=4, n=16, f=4', 'k=4, n=16, f=8', 'k=4, n=16, f=16'] 74
# range(0, 50)
# [[0.4443379 ]
#  [0.42587876]
#  [0.44697492]
#  [0.56360313]
#  [0.51302029]
#  [0.60987085]
#  [0.66596746]
#  [0.61706272]
#  [0.70408438]
#  [0.69881034]
#  [0.70732073]
#  [0.80788709]
#  [0.82358934]
#  [0.78319499]
#  [0.8129214 ]
#  [0.77899973]
#  [0.82838393]
#  [0.85151778]
#  [0.82227083]
#  [0.84061011]
#  [0.81232208]
#  [0.83293878]
#  [0.82706542]
#  [0.84192862]
#  [0.82275029]
#  [0.81579815]
#  [0.83126068]
#  [0.84660334]
#  [0.82095232]
#  [0.84552456]
#  [0.85882952]
#  [0.85487399]
#  [0.83245932]
#  [0.84084984]
#  [0.84948009]
#  [0.81927422]
#  [0.8545144 ]
#  [0.8599083 ]
#  [0.83977106]
#  [0.84912049]
#  [0.85703155]
#  [0.84780198]
#  [0.83941147]
#  [0.84864104]
#  [0.82970244]
#  [0.86817896]
#  [0.85235684]
#  [0.8751311 ]
#  [0.86470289]
#  [0.87597015]]
# b
# k=4, n=16, f=16

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}     
for dataset in datasets:

    log_root_path = os.path.join(root_path,f"{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}")

    filenames = []
    labels = []
    for k in k_list:
        for n in n_list:
            for f in f_list:
                filenames.append(f"ours++_fedpet_roberta-large_train_examples_64_f_{f}_n_{n}_k_{k}_filter_{filter[dataset]}.log")
                labels.append(f"k={k}, n={n}, f={f}")
                
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Runtime")
    plt.ylabel("Accuracy")
    for filename in filenames:

        log_path = os.path.join(log_root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        runtime = []
        train_runtime = []
        infer_runtime = []
        time_stamp = 0
        train_time_stamp = 0
        infer_time_stamp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                train_samples = list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]
                infer_samples = list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]

                # TX2: train, 1s/sample, infer, 0.5s/sample
                train_time = np.max(train_samples) * train_latency_list["tx2+bitfit"] if len(train_samples) > 0 else 0
                infer_time = np.max(infer_samples) * infer_latency_list["tx2+bitfit"] if len(infer_samples) > 0 else 0

                comm_time = communication_latency_list["bitfit"]
                
                time_stamp = time_stamp + train_time + infer_time + comm_time # elasped time of all clients / energy consumption
                train_time_stamp = train_time + train_time_stamp
                infer_time_stamp = infer_time + infer_time_stamp
                
            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

                runtime.append(time_stamp)
                train_runtime.append(train_time_stamp)
                infer_runtime.append(infer_time_stamp)

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")

        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, runtime is {runtime[idx]}")
        acc_list[dataset].append(this_max_acc)
        runtime_list[dataset].append(runtime[idx])
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(len(runtime),len(list(map(float, y_mean))))
        plt.plot(runtime[:len(y_mean)],np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=4)
    # fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=2,fontsize=15)
    fig.savefig(os.path.join(output_fig_path, f"eval-ablation-{dataset}-time-12.03.pdf"))
    t = t+1
# Out:
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_1_k_1_filter_0.2.log
# max accuracy is 0.7039225674987264, runtime is 5941.0
# 22 22
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_1_k_1_filter_0.2.log
# max accuracy is 0.6782475802343352, runtime is 3485.0
# 25 25
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_1_k_1_filter_0.2.log
# max accuracy is 0.723586347427407, runtime is 2153.0
# 25 25
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_1_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_1_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_2_k_1_filter_0.2.log
# max accuracy is 0.6009169638308711, runtime is 2677.0
# 19 19
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_2_k_1_filter_0.2.log
# max accuracy is 0.6902699949057565, runtime is 2816.0
# 21 21
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_2_k_1_filter_0.2.log
# max accuracy is 0.7096281202241467, runtime is 2405.0
# 25 25
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_2_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_2_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_4_k_1_filter_0.2.log
# max accuracy is 0.6752929190015283, runtime is 5690.0
# 19 19
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_4_k_1_filter_0.2.log
# max accuracy is 0.6454406520631686, runtime is 3031.0
# 19 19
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_4_k_1_filter_0.2.log
# max accuracy is 0.7200203769740193, runtime is 1633.0
# 21 21
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_4_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_4_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_8_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_8_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_8_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_8_k_1_filter_0.2.log
# max accuracy is 0.739174732552216, runtime is 3523.0
# 51 51
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_8_k_1_filter_0.2.log
# max accuracy is 0.7129903209373408, runtime is 2300.0
# 53 53
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_16_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_16_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_16_k_1_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_16_k_1_filter_0.2.log
# max accuracy is 0.7220580743759552, runtime is 3579.0
# 47 47
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_16_k_1_filter_0.2.log
# max accuracy is 0.7168619460010188, runtime is 2318.0
# 52 52
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_1_k_2_filter_0.2.log
# max accuracy is 0.5345899133978604, runtime is 6961.0
# 23 23
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_1_k_2_filter_0.2.log
# max accuracy is 0.7208354559347937, runtime is 5176.0
# 22 22
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_1_k_2_filter_0.2.log
# max accuracy is 0.7210392256749872, runtime is 2658.0
# 25 25
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_1_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_1_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_2_k_2_filter_0.2.log
# max accuracy is 0.5806418746816098, runtime is 5109.0
# 22 22
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_2_k_2_filter_0.2.log
# max accuracy is 0.5746306673458992, runtime is 5730.0
# 23 23
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_2_k_2_filter_0.2.log
# max accuracy is 0.705145185939888, runtime is 2134.0
# 22 22
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_2_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_2_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_4_k_2_filter_0.2.log
# max accuracy is 0.40804890473764643, runtime is 1320.0
# 17 17
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_4_k_2_filter_0.2.log
# max accuracy is 0.7370351502801834, runtime is 3678.0
# 19 19
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_4_k_2_filter_0.2.log
# max accuracy is 0.5718797758532858, runtime is 694.0
# 24 24
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_4_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_4_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_8_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_8_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_8_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_8_k_2_filter_0.2.log
# max accuracy is 0.7431482424859909, runtime is 5366.0
# 50 50
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_8_k_2_filter_0.2.log
# max accuracy is 0.723586347427407, runtime is 3217.0
# 53 53
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_16_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_16_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_16_k_2_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_16_k_2_filter_0.2.log
# max accuracy is 0.7162506367804381, runtime is 1965.0
# 47 47
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_16_k_2_filter_0.2.log
# max accuracy is 0.7387671930718288, runtime is 2448.0
# 51 51
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_1_k_4_filter_0.2.log
# max accuracy is 0.5375445746306673, runtime is 3135.0
# 23 23
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_1_k_4_filter_0.2.log
# max accuracy is 0.5816607233825777, runtime is 6404.0
# 22 22
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_1_k_4_filter_0.2.log
# max accuracy is 0.7204279164544065, runtime is 2382.0
# 22 22
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_1_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_1_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_2_k_4_filter_0.2.log
# max accuracy is 0.571777890983189, runtime is 2873.0
# 22 22
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_2_k_4_filter_0.2.log
# max accuracy is 0.4412633723892002, runtime is 5057.0
# 24 24
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_2_k_4_filter_0.2.log
# max accuracy is 0.717269485481406, runtime is 3767.0
# 22 22
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_2_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_2_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_4_k_4_filter_0.2.log
# max accuracy is 0.37768721344880285, runtime is 4.0
# 17 17
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_4_k_4_filter_0.2.log
# max accuracy is 0.37768721344880285, runtime is 4.0
# 20 20
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_4_k_4_filter_0.2.log
# max accuracy is 0.721141110545084, runtime is 3843.0
# 21 21
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_4_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_4_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_8_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_8_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_8_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_8_k_4_filter_0.2.log
# max accuracy is 0.6627610799796231, runtime is 7966.0
# 49 49
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_8_k_4_filter_0.2.log
# max accuracy is 0.7317371370351503, runtime is 5305.0
# 53 53
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_1_n_16_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_2_n_16_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_4_n_16_k_4_filter_0.2.log not exists
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_8_n_16_k_4_filter_0.2.log
# max accuracy is 0.6937340804890474, runtime is 3463.0
# 46 46
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_16_k_4_filter_0.2.log
# max accuracy is 0.7445746306673459, runtime is 5524.0
# 50 50

# %%
c=0
for dataset in datasets:
    np.random.seed(42)
    acc_list_tailored = np.random.choice(acc_list[dataset], 8, replace=False)
    runtime_list_tailored = np.random.choice(runtime_list[dataset], 8, replace=False)
    labels_tailored = np.random.choice(labels, 8, replace=False)
    colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]
    fig = plt.figure()
    plt.title(f"{dataset}")
    plt.xlabel("1-Acc")
    plt.ylabel("Runtime")
    plt.scatter(1- np.array(acc_list_tailored), np.array(runtime_list_tailored),s=150,color=colors[:len(acc_list_tailored)])
    for idx in range(len(acc_list_tailored)):
        plt.text(1-acc_list_tailored[idx], runtime_list_tailored[idx], labels_tailored[idx], fontsize=12)
    plt.savefig(os.path.join(output_fig_path, f"eval-ablation-{dataset}-sactter-12.03.pdf"))
    c=c+1

# %%
print(acc_list_tailored)
print(runtime_list_tailored)
print(labels_tailored)
# Out:
# [0.64544065 0.58166072 0.72002038 0.72205807 0.44126337 0.66276108
#  0.71726949 0.53754457]
# [5.109e+03 7.966e+03 5.057e+03 4.000e+00 2.134e+03 5.524e+03 3.031e+03
#  1.965e+03]
# ['k=2, n=1, f=16' 'k=2, n=2, f=8' 'k=4, n=16, f=4' 'k=4, n=4, f=8'
#  'k=2, n=2, f=2' 'k=1, n=1, f=4' 'k=2, n=16, f=2' 'k=4, n=4, f=16']

# %%
acc_list_tailored_fixed = np.array([0.64544065 0.58166072 0.72002038 0.72205807 0.44126337 0.66276108
 0.71726949 0.53754457]
)
runtime_list_tailored_fixed = np.array([5.109e+03 7.966e+03 5.057e+03 4.000e+00 2.134e+03 5.524e+03 3.031e+03
 1.965e+03])

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}    
trial = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}    
test_round = 5
for dataset in datasets:

    log_root_path = os.path.join(root_path,f"{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}")

    filenames = []
    labels = []
    for k in k_list:
        for n in n_list:
            for f in f_list:
                filenames.append(f"ours++_fedpet_roberta-large_train_examples_64_f_{f}_n_{n}_k_{k}_filter_{filter[dataset]}.log")
                labels.append(f"k={k}, n={n}, f={f}")
    
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Test round")
    plt.ylabel("AUG-E")
    # plt.ylim(-0.1,0.2)
    np.random.seed(42)
    filenames_show = np.random.choice(filenames, 8, replace=False)
    for filename in filenames:
        if filename not in filenames_show:
            continue
        log_path = os.path.join(log_root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 100
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        train_delta = []
        infer_delta = []
        acc_delta = []
        acc_tmp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                train_samples = list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]
                infer_samples = list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]
                # TX2: train, 1s/sample, infer, 0.5s/sample, no comm. because bit fit is parameter efficient.
                train_time = np.max(train_samples) * train_latency_list["tx2+bitfit"] if len(train_samples) > 0 else 0
                infer_time = np.max(infer_samples) * infer_latency_list["tx2+bitfit"] if len(infer_samples) > 0 else 0

                train_delta.append(train_time)
                infer_delta.append(infer_time)

            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc
                acc_delta.append(acc - acc_tmp)
                acc_tmp = acc
        
        print(df)
        infer_delta = [np.sum(np.array(infer_delta)) / len(infer_delta)] * len(infer_delta) # divide infer time into even time periods
        iter = len(df.index)
        
        # show_iter = 20
        show_iter = min(len(np.array(train_delta)), len(np.array(infer_delta)), len(np.array(acc_delta))) # make sure the length of three lists are the same

        train_gradient = np.array(acc_delta[:show_iter]) / np.array(train_delta[:show_iter])
        infer_gradient = np.array(acc_delta[:show_iter]) / np.array(infer_delta[:show_iter])

        curve = 100*np.array(acc_delta)[:show_iter] / (np.array(train_delta[:show_iter]) + np.array(infer_delta[:show_iter]))

        flag = 0
        curve_average = []
        tmp = 0
        for i in range(show_iter):
            if flag == test_round:
                curve_average.append(tmp)
                flag = 0
                tmp = 0
                continue
            else:
                tmp = tmp + curve[i]
                flag = flag + 1
        plt.plot(range(len(curve_average)), curve_average, label=labels[filenames.index(filename)], color=colors[filenames.index(filename)], linewidth=1)
        # plt.plot(range(len(train_gradient)),train_gradient,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=1, linestyle='-')
        # plt.plot(range(len(train_gradient)),infer_gradient,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=1, linestyle='--')
    # fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=1,fontsize=10)
    fig.savefig(os.path.join(output_fig_path, f"eval-ablation-{dataset}-metric-12.03.pdf"))
    t = t+1
# Out:
#            0
# 0   0.377687
# 1     0.3892
# 2   0.322058
# 3   0.574223
# 4   0.521345
# ..       ...
# 95       NaN
# 96       NaN
# 97       NaN
# 98       NaN
# 99       NaN
#
# [100 rows x 1 columns]
# /Users/cdq/Desktop/opensource/FedPrompt/data/ablation/pacing/pacing-configuration-12.3/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/ours++_fedpet_roberta-large_train_examples_64_f_16_n_1_k_1_filter_0.2.log not exists
#            0
# 0   0.377687
# 1   0.356903
# 2   0.362608
# 3   0.447376
# 4   0.483647
# ..       ...
# 95       NaN
# 96       NaN
# 97       NaN
# 98       NaN
# 99       NaN
#
# [100 rows x 1 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-d89adcb4f517> in <module>
#      90                 tmp = tmp + curve[i]
#      91                 flag = flag + 1
# ---> 92         plt.plot(range(len(curve_average)), curve_average, label=labels[filenames.index(filename)], color=colors[filenames.index(filename)], linewidth=1)
#      93         # plt.plot(range(len(train_gradient)),train_gradient,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=1, linestyle='-')
#      94         # plt.plot(range(len(train_gradient)),infer_gradient,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=1, linestyle='--')
#
# IndexError: list index out of range

# %%
trial
# Out:
# {'agnews': [], 'mnli': [], 'yahoo': [], 'yelp-full': []}
