# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import os

# %%
# roberta-large, seeds could be [6, 42, 99]
datasets = {"agnews": 1, "mnli": 0, "yahoo": 5, "yelp-full": 0}
all_client_num_in_total_list = {"agnews": 1000, "yahoo": 1000, "yelp-full": 1000, "mnli": 1000}
alphas = {"agnews": 1, "yahoo": 0, "yelp-full": 0, "mnli": 0}
gammas = {"agnews": 100, "yahoo": 100, "yelp-full": 100, "mnli": 100}
full_set_acc= {"agnews": 0.93, "yahoo": 0.78, "yelp-full": 0.7, "mnli": 0.85}

filenames = [
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log",
]

labels = ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10']
seed = 6

# source file/log
root_path = "/Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/"
output_fig_path = "/Users/cdq/Desktop/opensource/FedPrompt/figs/pacing"

# plot hyper-para.
colors=['r','g','b','y','c','m','k']

# %%
# round to accuracy
i=0
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
round_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
for dataset in datasets:

    log_root_path = os.path.join(root_path,f"{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}")


    fig = plt.figure()
    plt.title(dataset)
    for filename in filenames:
            
        log_path = os.path.join(log_root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue


        # plt.title(log_path)
        iter = 1000
        phrase = 'aggregated model performance is'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        for line in f:
            if phrase in line:
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")
            continue

        # print(filename)
        # print(df)
        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, round is {idx}")
        acc_list[dataset].append(this_max_acc)
        round_list[dataset].append(idx)
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(labels, filenames.index(filename))
        plt.plot(range(iter),np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)])
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
    fig.savefig(os.path.join(output_fig_path, f"a{i}.pdf"))
    i = i+1
# Out:
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.890921052631579, round is 53
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 0
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.8807894736842106, round is 49
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 1
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.8876315789473684, round is 40
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 2
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.8773684210526316, round is 41
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 3
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.8861842105263158, round is 19
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 4
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.8851315789473684, round is 54
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 5
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.5062659195109527, round is 29
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 0
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.6903718797758532, round is 45
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 1
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6156902699949057, round is 18
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 2
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.6477840040753948, round is 36
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 3
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.4456444218033622, round is 4
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 4
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.5593479368313805, round is 39
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 5
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.5510833333333334, round is 9
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 0
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.5772833333333334, round is 13
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 1
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6366166666666667, round is 9
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 2
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.5960333333333333, round is 11
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 3
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.5486666666666666, round is 9
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 4
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.5937333333333333, round is 11
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 5
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.52336, round is 14
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 0
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.56188, round is 15
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 1
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.5923, round is 9
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 2
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.54776, round is 14
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 3
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.55388, round is 6
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 4
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.53168, round is 10
# ['n, f = 1, 1', 'n, f = 1, 10', 'n, f = 5, 1', 'n, f = 5, 10', 'n, f = 10, 1', 'n, f = 10, 10'] 5

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}     
for dataset in datasets:

    log_root_path = os.path.join(root_path,f"{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}")
    
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Runtime")
    plt.ylabel("Accuracy")
    for filename in filenames:

        log_path = os.path.join(log_root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        runtime = []
        train_runtime = []
        infer_runtime = []
        time_stamp = 0
        train_time_stamp = 0
        infer_time_stamp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                # TX2: train, 1s/sample, infer, 0.5s/sample, no comm. because bit fit is parameter efficient.
                train_time = sum(list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]) * 1 
                infer_time = sum(list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]) * 0.5
                
                time_stamp = time_stamp + train_time + infer_time # elasped time of all clients / energy consumption
                train_time_stamp = train_time + train_time_stamp
                infer_time_stamp = infer_time + infer_time_stamp

                runtime.append(time_stamp)
                train_runtime.append(train_time_stamp)
                infer_runtime.append(infer_time_stamp)
            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")

        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, runtime is {runtime[idx]}")
        acc_list[dataset].append(this_max_acc)
        runtime_list[dataset].append(runtime[idx])
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(len(runtime),len(list(map(float, y_mean))))
        plt.plot(runtime[:len(y_mean)],y_mean,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=4)
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=2,fontsize=15)
    fig.savefig(os.path.join(output_fig_path, f"b{t}.pdf"))
    t = t+1
# Out:
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.890921052631579, runtime is 12709.5
# 58 57
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.8807894736842106, runtime is 858.0
# 59 58
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.8876315789473684, runtime is 20997.5
# 55 55
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.8773684210526316, runtime is 1918.5
# 57 56
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.8861842105263158, runtime is 14032.5
# 46 46
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/agnews/all_1000/seed_6/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.8851315789473684, runtime is 4460.5
# 57 57
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.5062659195109527, runtime is 13887.5
# 36 35
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.6903718797758532, runtime is 1626.0
# 46 46
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6156902699949057, runtime is 24179.5
# 33 33
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.6477840040753948, runtime is 4128.0
# 48 48
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.4456444218033622, runtime is 8041.0
# 30 30
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/mnli/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.5593479368313805, runtime is 7805.5
# 46 45
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.5510833333333334, runtime is 7255.0
# 12 11
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.5772833333333334, runtime is 827.0
# 15 14
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6366166666666667, runtime is 36511.0
# 10 10
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.5960333333333333, runtime is 3786.0
# 14 13
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.5486666666666666, runtime is 67738.0
# 10 10
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yahoo/all_1000/seed_6/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.5937333333333333, runtime is 7281.5
# 14 13
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.52336, runtime is 6196.5
# 16 15
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.56188, runtime is 466.0
# 17 16
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.5923, runtime is 17015.0
# 14 13
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.54776, runtime is 1850.0
# 16 16
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.55388, runtime is 20423.0
# 14 14
# /Users/cdq/Desktop/opensource/FedPrompt/data/log/pacing-11.19/yelp-full/all_1000/seed_6/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.53168, runtime is 3361.5
# 16 15

# %%
c=0
for dataset in datasets:
    fig = plt.figure()
    plt.title(f"{dataset}")
    plt.xlabel("1-Acc")
    plt.ylabel("Runtime")
    plt.scatter(1- np.array(acc_list[dataset]), np.array(runtime_list[dataset]),s=150,color=colors[:len(acc_list[dataset])])
    for idx in range(len(acc_list[dataset])):
        plt.text(1-acc_list[dataset][idx], runtime_list[dataset][idx], labels[idx], fontsize=12)
    plt.savefig(os.path.join(output_fig_path, f"c{c}.pdf"))
    c=c+1

# %%
train_runtime
# Out:
# [8, 15, 22, 29, 35, 43, 51, 58, 67, 75, 112, 174, 237, 272, 280, 306]

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}    
trial = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}    
test_round = 5
for dataset in datasets:

    log_root_path = os.path.join(root_path,f"{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}")
    
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Test round")
    plt.ylabel("AUG-E")
    # plt.ylim(-0.1,0.2)
    for filename in filenames:

        log_path = os.path.join(log_root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        train_delta = []
        infer_delta = []
        acc_delta = []
        acc_tmp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                # TX2: train, 1s/sample, infer, 0.5s/sample, no comm. because bit fit is parameter efficient.
                train_time = sum(list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]) * 1 
                infer_time = sum(list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]) * 0.5

                train_delta.append(train_time)
                infer_delta.append(infer_time)

            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc
                acc_delta.append(acc - acc_tmp)
                acc_tmp = acc
        
        
        infer_delta = [np.sum(np.array(infer_delta)) / len(infer_delta)] * len(infer_delta) # divide infer time into even time periods
        iter = len(df.index)
        
        # show_iter = 20
        show_iter = min(len(np.array(train_delta)), len(np.array(infer_delta)), len(np.array(acc_delta))) # make sure the length of three lists are the same

        train_gradient = np.array(acc_delta[:show_iter]) / np.array(train_delta[:show_iter])
        infer_gradient = np.array(acc_delta[:show_iter]) / np.array(infer_delta[:show_iter])

        curve = 100*np.array(acc_delta)[:show_iter] / (np.array(train_delta[:show_iter]) + np.array(infer_delta[:show_iter]))

        flag = 0
        curve_average = []
        tmp = 0
        for i in range(show_iter):
            if flag == test_round:
                curve_average.append(tmp)
                flag = 0
                tmp = 0
                continue
            else:
                tmp = tmp + curve[i]
                flag = flag + 1
        plt.plot(range(len(curve_average)), curve_average, label=labels[filenames.index(filename)], color=colors[filenames.index(filename)], linewidth=1)
        # plt.plot(range(len(train_gradient)),train_gradient,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=1, linestyle='-')
        # plt.plot(range(len(train_gradient)),infer_gradient,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=1, linestyle='--')
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=1,fontsize=10)
    fig.savefig(os.path.join(output_fig_path, f"d{t}.pdf"))
    t = t+1
