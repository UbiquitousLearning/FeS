# %%
import matplotlib.pyplot as plt

layers_bitfit = [24, 16, 8, 1]
acc_bitfit = [0.767, 0.6006, 0.345, 0.399]

layers_full = [24, 16, 15, 14, 13, 12, 8, 1]
acc_full = [0.761, 0.7362, 0.758, 0.451, 0.371, 0.321, 0.395, 0.317
]

fig = plt.figure()
plt.title("mnli")
plt.xlabel("# layers")
plt.ylabel("Convergence accuracy")
plt.scatter(layers_bitfit, acc_bitfit, s=20,color='r',linewidths=5)
plt.plot(layers_bitfit, acc_bitfit,color='r', linestyle = '--', label = 'bitfit')

plt.scatter(layers_full, acc_full, s=20,color='b',linewidths=5)
plt.plot(layers_full, acc_full,color='b', linestyle = '-', label = 'w/o bitfit')
fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
fig.savefig("./mnli.png")

# %%
import matplotlib.pyplot as plt

layers_bitfit = [24, 16, 8, 1]
acc_bitfit = [0.692, 0.697, 0.670, 0.523]

layers_full = [24, 16, 8, 1]
acc_full = [0.674
, 0.703
, 0.6881, 0.578]

fig = plt.figure()
plt.title("yahoo")
plt.xlabel("# layers")
plt.ylabel("Convergence accuracy")
plt.scatter(layers_bitfit, acc_bitfit, s=20,color='r',linewidths=5)
plt.plot(layers_bitfit, acc_bitfit,color='r', linestyle = '--', label = 'bitfit')

plt.scatter(layers_full, acc_full, s=20,color='b',linewidths=5)
plt.plot(layers_full, acc_full,color='b', linestyle = '-', label = 'w/o bitfit')
fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
fig.savefig("./yahoo.png")

# %%
import matplotlib.pyplot as plt

layers_bitfit = [24, 16, 8, 1]
acc_bitfit = [0.876, 0.891, 0.875, 0.861]

layers_full = [12, 8]
acc_full = [0.8507,0.849]

fig = plt.figure()
plt.title("agnews")
plt.xlabel("# layers")
plt.ylabel("Convergence accuracy")
plt.scatter(layers_bitfit, acc_bitfit, s=20,color='r',linewidths=5)
plt.plot(layers_bitfit, acc_bitfit,color='r', linestyle = '--', label = 'bitfit')

plt.scatter(layers_full, acc_full, s=20,color='b',linewidths=5)
plt.plot(layers_full, acc_full,color='b', linestyle = '-', label = 'w/o bitfit')
fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
fig.savefig("./agnews.png")

# %%
import matplotlib.pyplot as plt

layers_bitfit = [24,20,16,14,12,10,8,6,4,1]
acc_bitfit = [0.608, 0.591, 0.609, 0.583, 0.584, 0.575, 0.560, 0.555, 0.506, 0.491]

layers_full = [12, 8,4]
acc_full = [0.566, 0.529, 0.524]

fig = plt.figure()
plt.title("yelp")
plt.xlabel("# layers")
plt.ylabel("Convergence accuracy")
plt.scatter(layers_bitfit, acc_bitfit, s=20,color='r',linewidths=5)
plt.plot(layers_bitfit, acc_bitfit,color='r', linestyle = '--', label = 'bitfit')

plt.scatter(layers_full, acc_full, s=20,color='b',linewidths=5)
plt.plot(layers_full, acc_full,color='b', linestyle = '-', label = 'w/o bitfit')
fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
fig.savefig("./yelp.png")
