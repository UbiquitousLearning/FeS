# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import os

# %%
datasets = {"agnews": 1 , "mnli": 0, "yahoo": 5, "yelp-full": 0} # 
all_client_num_in_total_list = {"agnews": 100, "yahoo": 1000, "yelp-full": 1000, "mnli": 1000}
alphas = {"agnews": 1, "yahoo": 0, "yelp-full": 0, "mnli": 0}
gammas = {"agnews": 0.001, "yahoo": 0.001, "yelp-full": 0.001, "mnli": 100}
full_set_acc= {"agnews": 0.93, "yahoo": 0.78, "yelp-full": 0.7, "mnli": 0.85}

filenames = [
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log",
    "random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log"
]

labels = ["filter 0.1", "filter 0.001", "filter 0.2", "filter 0.5", "filter 0.005", "filter 1", "no filter", "random filter 0.1", "random filter 0.001", "random filter 0.2", "random filter 0.5", "random filter 0.05", "random filter 1"]

seed = 42

#

# %%
colors=['r','g','b','y','m','k', 'c','r','g','b','y', 'm','k']# 'm','k'
linestyle=['-','-','-','-','-','-','-','--','--','--','--','--','--']
linewidths = [0,0,0,0,0,0,0,1.5,1.5,1.5,1.5,1.5,1.5]

# %%
# round to accuracy
i=0
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
round_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
for dataset in datasets:

    root_path = f"/home/cdq/FedPet/log/z-obsoleted/filter-11.19/{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}"


    fig = plt.figure()
    plt.title(dataset)
    for filename in filenames:
            
        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue


        # plt.title(log_path)
        iter = 1000
        phrase = 'aggregated model performance is'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        for line in f:
            if phrase in line:
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")
            continue

        # print(filename)
        # print(df)
        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, round is {idx}")
        acc_list[dataset].append(this_max_acc)
        round_list[dataset].append(idx)
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(labels, filenames.index(filename))
        plt.plot(range(iter),np.array(y_mean)/full_set_acc[dataset],label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linestyle=linestyle[filenames.index(filename)])
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
    fig.savefig(f"../fig/a{i}.pdf")
    i = i+1
# Out:
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.8905263157894737, round is 43
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 0
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log
# max accuracy is 0.8855263157894737, round is 46
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 1
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.8830263157894737, round is 8
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 2
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.8873684210526316, round is 10
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 3
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log
# max accuracy is 0.8809210526315789, round is 18
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 4
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.8843421052631579, round is 11
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 5
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.8572368421052632, round is 9
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 6
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.8747368421052631, round is 11
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 7
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log
# max accuracy is 0.8851315789473684, round is 27
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 8
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.8759210526315789, round is 11
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 9
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.8830263157894737, round is 24
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 10
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log
# max accuracy is 0.8725, round is 18
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 11
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.8789473684210526, round is 10
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 12
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.6820173204279164, round is 111
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 0
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log
# max accuracy is 0.6982170147733061, round is 120
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 1
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.7471217524197656, round is 80
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 2
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.7343861436576669, round is 38
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 3
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log
# max accuracy is 0.590728476821192, round is 63
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 4
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.5721854304635762, round is 73
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 5
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.7797249108507387, round is 69
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 6
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.7282730514518594, round is 76
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 7
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log
# max accuracy is 0.5230769230769231, round is 19
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 8
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.7145185939887927, round is 27
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 9
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log
# max accuracy is 0.43107488537952116, round is 5
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 10
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log
# max accuracy is 0.7316352521650535, round is 86
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 11
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log
# max accuracy is 0.6220071319409067, round is 38
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 12
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log
# max accuracy is 0.66135, round is 26
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 0
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log
# max accuracy is 0.6488833333333334, round is 19
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 1
# /home/cdq/FedPet/log/z-obsoleted/filter-11.19/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log
# max accuracy is 0.6703, round is 21
# ['filter 0.1', 'filter 0.001', 'filter 0.2', 'filter 0.5', 'filter 0.005', 'filter 1', 'no filter', 'random filter 0.1', 'random filter 0.001', 'random filter 0.2', 'random filter 0.5', 'random filter 0.05', 'random filter 1'] 2

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}     
for dataset in datasets:

    root_path = f"/home/cdq/FedPet/log/z-obsoleted/filter-11.19/{dataset}/all_{all_client_num_in_total_list[dataset]}/seed_{seed}/pattern_{datasets[dataset]}/alpha_{alphas[dataset]}_beta_0_gamma_{gammas[dataset]}"
    
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Runtime")
    plt.ylabel("Accuracy")
    for filename in filenames:

        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        runtime = []
        train_runtime = []
        infer_runtime = []
        time_stamp = 0
        train_time_stamp = 0
        infer_time_stamp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                # TX2: train, 1s/sample, infer, 0.5s/sample, no comm. because bit fit is parameter efficient.
                train_time = sum(list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]) * 1 
                infer_time = sum(list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]) * 0.5
                
                time_stamp = time_stamp + train_time + infer_time # elasped time of all clients / energy consumption
                train_time_stamp = train_time + train_time_stamp
                infer_time_stamp = infer_time + infer_time_stamp

                runtime.append(time_stamp)
                train_runtime.append(train_time_stamp)
                infer_runtime.append(infer_time_stamp)
            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")

        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, runtime is {runtime[idx]}")
        acc_list[dataset].append(this_max_acc)
        runtime_list[dataset].append(runtime[idx])
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(len(runtime),len(list(map(float, y_mean))))
        plt.plot(runtime[:len(y_mean)],y_mean,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=4,linestyle=linestyle[filenames.index(filename)])
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=2,fontsize=15)
    fig.savefig(f"../fig/b{t}.pdf")
    t = t+1
# Out:
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.8773684210526316, runtime is 37815.0
# 45 45
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log not exists
# /home/cdq/FedPet/log/agnews/all_100/seed_42/pattern_1/alpha_1_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.774223127865512, runtime is 108708.5
# 60 60
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log not exists
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.6183, runtime is 50286.0
# 14 14
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log not exists
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_-1.log
# max accuracy is 0.49208, runtime is 5557.0
# 25 24
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.1.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.01.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.2.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.5.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_0.05.log not exists
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_0.001/random_stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1_filter_1.log not exists

# %%
c=0
for dataset in datasets:
    fig = plt.figure()
    plt.title(f"{dataset}")
    plt.xlabel("1-Acc")
    plt.ylabel("Runtime")
    plt.scatter(1- np.array(acc_list[dataset]), np.array(runtime_list[dataset]),s=150,color=colors[:len(acc_list[dataset])],edgecolors='k',linewidths=linewidths[:len(acc_list[dataset])])
    for idx in range(len(acc_list[dataset])):
        plt.text(1-acc_list[dataset][idx], runtime_list[dataset][idx], labels[idx], fontsize=12)
    # plt.text(1- np.array(acc_list[dataset]), np.array(runtime_list[dataset]))
    plt.savefig(f"../fig/c{c}.pdf")
    c=c+1

# %%
acc_list
# Out:
# {'agnews': [0.8905263157894737,
#   0.8855263157894737,
#   0.8830263157894737,
#   0.8873684210526316,
#   0.8809210526315789,
#   0.8843421052631579,
#   0.8572368421052632,
#   0.8747368421052631,
#   0.8851315789473684,
#   0.8759210526315789,
#   0.8830263157894737,
#   0.8725,
#   0.8789473684210526],
#  'mnli': [0.6820173204279164,
#   0.6982170147733061,
#   0.7471217524197656,
#   0.7343861436576669,
#   0.590728476821192,
#   0.5721854304635762,
#   0.7797249108507387,
#   0.7282730514518594,
#   0.5230769230769231,
#   0.7145185939887927,
#   0.43107488537952116,
#   0.7316352521650535,
#   0.6220071319409067],
#  'yahoo': [0.66135,
#   0.6488833333333334,
#   0.6703,
#   0.65765,
#   0.6605333333333333,
#   0.6584,
#   0.6616833333333333,
#   0.6488666666666667,
#   0.6724,
#   0.6515,
#   0.6593333333333333,
#   0.66835,
#   0.6529333333333334],
#  'yelp-full': [0.59498,
#   0.57634,
#   0.61142,
#   0.6207,
#   0.5939,
#   0.60478,
#   0.51584,
#   0.60974,
#   0.58922,
#   0.60372,
#   0.60274,
#   0.5986,
#   0.51436]}
