# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import os

# %%
datasets = {"agnews": 1, "mnli": 0, "yahoo": 5, "yelp-full": 0}

filenames = [
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log",
    "stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log",
    "fedpet_64_32_roberta-large.log"
]

labels = ["1_1", "1_10", "5_1", "5_10", "10_1", "10_10","baseline"]

seed = 42

# %%
colors=['r','g','b','y','c','m','k']

# %%
# round to accuracy
i=0
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
round_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
for dataset in datasets:
    if dataset == "agnews":
        root_path = f"/home/cdq/FedPet/log/{dataset}/all_1000/seed_{seed}/pattern_{datasets[dataset]}/alpha_1_beta_0_gamma_100"
    else:
        root_path = f"/home/cdq/FedPet/log/{dataset}/all_1000/seed_{seed}/pattern_{datasets[dataset]}/alpha_0_beta_0_gamma_100"

    fig = plt.figure()
    plt.title(dataset)
    for filename in filenames:
            
        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue


        # plt.title(log_path)
        iter = 1000
        phrase = 'aggregated model performance is'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        for line in f:
            if phrase in line:
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")
            continue

        # print(filename)
        # print(df)
        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, round is {idx}")
        acc_list[dataset].append(this_max_acc)
        round_list[dataset].append(idx)
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(labels, filenames.index(filename))
        plt.plot(range(iter),y_mean,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)])
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.1),bbox_transform=fig.transFigure)
    fig.savefig(f"../fig/a{i}.png")
    i = i+1
# Out:
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.8981578947368422, round is 117
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 0
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.8902631578947369, round is 135
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 1
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.89, round is 68
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 2
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.8964473684210527, round is 71
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 3
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.8868421052631579, round is 67
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 4
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.9002631578947369, round is 98
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 5
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/fedpet_64_32_roberta-large.log
# max accuracy is 0.8755263157894737, round is 18
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 6
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.7136016301579216, round is 61
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 0
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.7355068772287315, round is 108
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 1
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.7923586347427407, round is 85
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 2
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.7718797758532858, round is 93
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 3
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.3779928680590932, round is 5
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 4
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.6962812022414672, round is 107
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 5
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/fedpet_64_32_roberta-large.log
# max accuracy is 0.4118186449312277, round is 5
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 6
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.6274833333333333, round is 11
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 0
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.59905, round is 22
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 1
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6753166666666667, round is 22
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 2
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.6817666666666666, round is 11
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 3
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.5952166666666666, round is 21
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 4
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.6222833333333333, round is 24
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 5
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/fedpet_64_32_roberta-large.log
# max accuracy is 0.40413333333333334, round is 3
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 6
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.5444, round is 15
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 0
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.585, round is 29
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 1
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6107, round is 28
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 2
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.60762, round is 31
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 3
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.524, round is 12
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 4
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.599, round is 21
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 5
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/fedpet_64_32_roberta-large.log
# max accuracy is 0.471, round is 4
# ['1_1', '1_10', '5_1', '5_10', '10_1', '10_10', 'baseline'] 6

# %%
# time to accuracy  
t = 0   
acc_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}
runtime_list = {"agnews": [], "mnli": [], "yahoo": [], "yelp-full": []}     
for dataset in datasets:
    if dataset == "agnews":
        root_path = f"/home/cdq/FedPet/log/{dataset}/all_1000/seed_{seed}/pattern_{datasets[dataset]}/alpha_1_beta_0_gamma_100"
    else:
        root_path = f"/home/cdq/FedPet/log/{dataset}/all_1000/seed_{seed}/pattern_{datasets[dataset]}/alpha_0_beta_0_gamma_100"
    fig = plt.figure()
    plt.title(dataset)
    plt.xlabel("Runtime")
    plt.ylabel("Accuracy")
    for filename in filenames:

        log_path = os.path.join(root_path, filename)
        if not os.path.exists(log_path):
            print(f"{log_path} not exists")
            continue

        iter = 1000
        phrase = 'train data'
        with open(log_path) as f:
            f = f.readlines()
        df = pd.DataFrame(data=None, index = range(iter), columns = range(1))
        runtime = []
        train_runtime = []
        infer_runtime = []
        time_stamp = 0
        train_time_stamp = 0
        infer_time_stamp = 0

        for line in f:
            if phrase in line:
                line_idx = f.index(line)
                
                train_info = f[line_idx]
                infer_info = f[line_idx + 1]
                
                # TX2: train, 1s/sample, infer, 0.5s/sample
                train_time = sum(list(map(int, re.findall(r'\d+', train_info.split("Gen")[1])))[1:]) * 1 
                infer_time = sum(list(map(int, re.findall(r'\d+', infer_info.split("Gen")[1])))[1:]) * 0.5
                
                time_stamp = time_stamp + train_time + infer_time # elasped time of all clients / energy consumption
                train_time_stamp = train_time + train_time_stamp
                infer_time_stamp = infer_time + infer_time_stamp

                runtime.append(time_stamp)
                train_runtime.append(train_time_stamp)
                infer_runtime.append(infer_time_stamp)
            if 'aggregated model performance is' in line: 
                gen = int(re.findall(r'Gen (.+?) ',line)[0])
                
                acc = float(re.findall(r': ?(\d+\.\d+)',line)[0])
                df[0][gen]=acc

        df = df.dropna(axis=0, how='any') # any 只要有 nan 就会删掉。 all　是必须全是nan才删除; 0: 行；1：列
        if df.empty:
            print(f"Bug: {log_path}")

        this_max_acc = np.max(df[0])
        idx = [df[0].to_list().index(x) for x in df[0] if x == this_max_acc][0]
        print(log_path)
        print(f"max accuracy is {this_max_acc}, runtime is {runtime[idx]}")
        acc_list[dataset].append(this_max_acc)
        runtime_list[dataset].append(runtime[idx])
        # df.to_csv("/Users/cdq/Desktop/opensource/FedPrompt/data/softlabel/agnews_aug_fedpet_128_32_roberta-large.csv")
        iter = len(df.index)
        y_mean = []
        for j in range(iter):
            y = np.array(df.iloc[j])

            y_mean.append(pd.DataFrame(y).dropna().mean())
            # plt.scatter(j, y)
        print(len(runtime),len(list(map(float, y_mean))))
        plt.plot(runtime[:len(y_mean)],y_mean,label=labels[filenames.index(filename)],color=colors[filenames.index(filename)],linewidth=4)
    fig.legend(loc="lower right",bbox_to_anchor=(0.9,0.2),bbox_transform=fig.transFigure,ncol=2,fontsize=15)
    fig.savefig(f"../fig/b{t}.png")
    t = t+1
# Out:
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.8981578947368422, runtime is 41316.0
# 131 131
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.8902631578947369, runtime is 5107.0
# 138 138
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.89, runtime is 43622.5
# 120 119
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.8964473684210527, runtime is 8387.5
# 146 145
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.8868421052631579, runtime is 64285.5
# 123 123
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.9002631578947369, runtime is 10545.0
# 136 135
# /home/cdq/FedPet/log/agnews/all_1000/seed_42/pattern_1/alpha_1_beta_0_gamma_100/fedpet_64_32_roberta-large.log
# max accuracy is 0.8755263157894737, runtime is 175.0
# 23 23
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.7136016301579216, runtime is 49670.5
# 101 100
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.7355068772287315, runtime is 8636.0
# 117 117
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.7923586347427407, runtime is 186544.5
# 88 87
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.7718797758532858, runtime is 26524.0
# 120 119
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.3779928680590932, runtime is 10044.0
# 89 89
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.6962812022414672, runtime is 39408.0
# 110 110
# /home/cdq/FedPet/log/mnli/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/fedpet_64_32_roberta-large.log
# max accuracy is 0.4118186449312277, runtime is 49.0
# 20 19
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.6274833333333333, runtime is 10316.5
# 26 25
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.59905, runtime is 1669.0
# 28 27
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6753166666666667, runtime is 115421.0
# 24 23
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.6817666666666666, runtime is 5850.0
# 30 29
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.5952166666666666, runtime is 181606.0
# 25 24
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.6222833333333333, runtime is 15966.0
# 27 26
# /home/cdq/FedPet/log/yahoo/all_1000/seed_42/pattern_5/alpha_0_beta_0_gamma_100/fedpet_64_32_roberta-large.log
# max accuracy is 0.40413333333333334, runtime is 32.0
# 5 4
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_1.log
# max accuracy is 0.5444, runtime is 7078.5
# 31 30
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_1_10.log
# max accuracy is 0.585, runtime is 1054.0
# 31 30
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_1.log
# max accuracy is 0.6107, runtime is 72144.0
# 29 29
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_5_10.log
# max accuracy is 0.60762, runtime is 7953.0
# 35 34
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_1.log
# max accuracy is 0.524, runtime is 43775.0
# 32 31
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/stale_aug_5_conver_0_limit_0_fedpet_64_32_roberta-large_10_10.log
# max accuracy is 0.599, runtime is 7321.0
# 32 31
# /home/cdq/FedPet/log/yelp-full/all_1000/seed_42/pattern_0/alpha_0_beta_0_gamma_100/fedpet_64_32_roberta-large.log
# max accuracy is 0.471, runtime is 41.0
# 6 5

# %%
c=0
for dataset in datasets:
    fig = plt.figure()
    plt.title(f"{dataset}")
    plt.xlabel("1-Acc")
    plt.ylabel("Runtime")
    plt.scatter(1- np.array(acc_list[dataset]), np.array(runtime_list[dataset]),s=150,color=['r','g','b','y','c','m'])
    plt.savefig(f"../fig/c{c}.png")
    c=c+1
